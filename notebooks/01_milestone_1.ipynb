# %%
import pandas as pd
df = pd.read_csv('../data/raw/GlobalWeatherRepository.csv')

# %%
# rows/columns
df.shape
# Out:
# (97240, 41)

# %%
df.columns.tolist()
# Out:
# ['country',
#  'location_name',
#  'latitude',
#  'longitude',
#  'timezone',
#  'last_updated_epoch',
#  'last_updated',
#  'temperature_celsius',
#  'temperature_fahrenheit',
#  'condition_text',
#  'wind_mph',
#  'wind_kph',
#  'wind_degree',
#  'wind_direction',
#  'pressure_mb',
#  'pressure_in',
#  'precip_mm',
#  'precip_in',
#  'humidity',
#  'cloud',
#  'feels_like_celsius',
#  'feels_like_fahrenheit',
#  'visibility_km',
#  'visibility_miles',
#  'uv_index',
#  'gust_mph',
#  'gust_kph',
#  'air_quality_Carbon_Monoxide',
#  'air_quality_Ozone',
#  'air_quality_Nitrogen_dioxide',
#  'air_quality_Sulphur_dioxide',
#  'air_quality_PM2.5',
#  'air_quality_PM10',
#  'air_quality_us-epa-index',
#  'air_quality_gb-defra-index',
#  'sunrise',
#  'sunset',
#  'moonrise',
#  'moonset',
#  'moon_phase',
#  'moon_illumination']

# %%
df.head(5)
# Out:
#        country     location_name  latitude  longitude        timezone  \
# 0  Afghanistan             Kabul     34.52      69.18      Asia/Kabul
# 1      Albania            Tirana     41.33      19.82   Europe/Tirane
# 2      Algeria           Algiers     36.76       3.05  Africa/Algiers
# 3      Andorra  Andorra La Vella     42.50       1.52  Europe/Andorra
# 4       Angola            Luanda     -8.84      13.23   Africa/Luanda
#
#    last_updated_epoch      last_updated  temperature_celsius  \
# 0          1715849100  16-05-2024 13:15                 26.6
# 1          1715849100  16-05-2024 10:45                 19.0
# 2          1715849100  16-05-2024 09:45                 23.0
# 3          1715849100  16-05-2024 10:45                  6.3
# 4          1715849100  16-05-2024 09:45                 26.0
#
#    temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 0                    79.8  Partly Cloudy  ...                8.4
# 1                    66.2  Partly cloudy  ...                1.1
# 2                    73.4          Sunny  ...               10.4
# 3                    43.3  Light drizzle  ...                0.7
# 4                    78.8  Partly cloudy  ...              183.4
#
#    air_quality_PM10  air_quality_us-epa-index air_quality_gb-defra-index  \
# 0              26.6                         1                          1
# 1               2.0                         1                          1
# 2              18.4                         1                          1
# 3               0.9                         1                          1
# 4             262.3                         5                         10
#
#    sunrise   sunset  moonrise   moonset      moon_phase  moon_illumination
# 0  4:50 AM  6:50 PM  12:12 PM   1:11 AM  Waxing Gibbous                 55
# 1  5:21 AM  7:54 PM  12:58 PM   2:14 AM  Waxing Gibbous                 55
# 2  5:40 AM  7:50 PM   1:15 PM   2:14 AM  Waxing Gibbous                 55
# 3  6:31 AM  9:11 PM   2:12 PM   3:31 AM  Waxing Gibbous                 55
# 4  6:12 AM  5:55 PM   1:17 PM  12:38 AM  Waxing Gibbous                 55
#
# [5 rows x 41 columns]

# %%
# Descriptive statistics
df.describe()
# Out:
#            latitude     longitude  last_updated_epoch  temperature_celsius  \
# count  97240.000000  97240.000000        9.724000e+04         97240.000000
# mean      19.145672     22.114266        1.737498e+09            22.790612
# std       24.457627     65.819962        1.249742e+07             8.895832
# min      -41.300000   -175.200000        1.715849e+09           -24.900000
# 25%        3.750000     -6.836100        1.726743e+09            18.100000
# 50%       17.250000     23.316700        1.737541e+09            25.000000
# 75%       40.400000     50.580000        1.748336e+09            28.300000
# max       64.150000    179.220000        1.759047e+09            49.200000
#
#        temperature_fahrenheit      wind_mph      wind_kph   wind_degree  \
# count            97240.000000  97240.000000  97240.000000  97240.000000
# mean                73.024825      8.243009     13.269109    170.873601
# std                 16.012298      7.885557     12.688198    102.713844
# min                -12.800000      2.200000      3.600000      1.000000
# 25%                 64.600000      4.000000      6.500000     83.000000
# 50%                 77.000000      6.900000     11.200000    165.000000
# 75%                 82.900000     11.400000     18.400000    256.000000
# max                120.600000   1841.200000   2963.200000    360.000000
#
#         pressure_mb   pressure_in  ...      gust_kph  \
# count  97240.000000  97240.000000  ...  97240.000000
# mean    1013.964613     29.941723  ...     18.560137
# std       11.388608      0.336250  ...     14.688076
# min      947.000000     27.960000  ...      3.600000
# 25%     1010.000000     29.830000  ...     10.500000
# 50%     1013.000000     29.920000  ...     15.900000
# 75%     1017.000000     30.050000  ...     24.400000
# max     3006.000000     88.770000  ...   2970.400000
#
#        air_quality_Carbon_Monoxide  air_quality_Ozone  \
# count                 97240.000000       97240.000000
# mean                    517.538150          62.801112
# std                     845.100253          32.269620
# min                   -9999.000000           0.000000
# 25%                     238.650000          42.000000
# 50%                     327.450000          60.000000
# 75%                     507.400000          79.000000
# max                   38879.398000         480.700000
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# count                  97240.000000                 97240.000000
# mean                      15.807415                    11.270508
# std                       26.067670                    40.837907
# min                        0.000000                 -9999.000000
# 25%                        1.295000                     0.800000
# 50%                        4.900000                     2.405000
# 75%                       17.945000                     9.065000
# max                      427.700000                   521.330000
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# count       97240.000000      97240.000000              97240.000000
# mean           26.167867         53.784536                  1.760911
# std            40.855679        164.293592                  0.981908
# min             0.168000      -1848.150000                  1.000000
# 25%             7.400000         10.900000                  1.000000
# 50%            15.170000         22.200000                  1.000000
# 75%            29.970000         46.065000                  2.000000
# max          1614.100000       6037.290000                  6.000000
#
#        air_quality_gb-defra-index  moon_illumination
# count                97240.000000       97240.000000
# mean                     2.761940          49.719971
# std                      2.568171          35.122040
# min                      1.000000           0.000000
# 25%                      1.000000          15.000000
# 50%                      2.000000          50.000000
# 75%                      3.000000          85.000000
# max                     10.000000         100.000000
#
# [8 rows x 30 columns]

# %%
# types and non-null counts.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 97240 entries, 0 to 97239
# Data columns (total 41 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   country                       97240 non-null  object
#  1   location_name                 97240 non-null  object
#  2   latitude                      97240 non-null  float64
#  3   longitude                     97240 non-null  float64
#  4   timezone                      97240 non-null  object
#  5   last_updated_epoch            97240 non-null  int64
#  6   last_updated                  97240 non-null  object
#  7   temperature_celsius           97240 non-null  float64
#  8   temperature_fahrenheit        97240 non-null  float64
#  9   condition_text                97240 non-null  object
#  10  wind_mph                      97240 non-null  float64
#  11  wind_kph                      97240 non-null  float64
#  12  wind_degree                   97240 non-null  int64
#  13  wind_direction                97240 non-null  object
#  14  pressure_mb                   97240 non-null  int64
#  15  pressure_in                   97240 non-null  float64
#  16  precip_mm                     97240 non-null  float64
#  17  precip_in                     97240 non-null  float64
#  18  humidity                      97240 non-null  int64
#  19  cloud                         97240 non-null  int64
#  20  feels_like_celsius            97240 non-null  float64
#  21  feels_like_fahrenheit         97240 non-null  float64
#  22  visibility_km                 97240 non-null  float64
#  23  visibility_miles              97240 non-null  int64
#  24  uv_index                      97240 non-null  float64
#  25  gust_mph                      97240 non-null  float64
#  26  gust_kph                      97240 non-null  float64
#  27  air_quality_Carbon_Monoxide   97240 non-null  float64
#  28  air_quality_Ozone             97240 non-null  float64
#  29  air_quality_Nitrogen_dioxide  97240 non-null  float64
#  30  air_quality_Sulphur_dioxide   97240 non-null  float64
#  31  air_quality_PM2.5             97240 non-null  float64
#  32  air_quality_PM10              97240 non-null  float64
#  33  air_quality_us-epa-index      97240 non-null  int64
#  34  air_quality_gb-defra-index    97240 non-null  int64
#  35  sunrise                       97240 non-null  object
#  36  sunset                        97240 non-null  object
#  37  moonrise                      97240 non-null  object
#  38  moonset                       97240 non-null  object
#  39  moon_phase                    97240 non-null  object
#  40  moon_illumination             97240 non-null  int64
# dtypes: float64(21), int64(9), object(11)
# memory usage: 30.4+ MB

# %%
df['country'].nunique(), df['location_name'].nunique()
# Out:
# (211, 254)

# %% [markdown]
# # Missing Values

# %% [markdown]
# ### Identify Missing Values

# %%
def make_data_dict(df):
    rows = []
    for c in df.columns:
        dtype = str(df[c].dtype)
        n_missing = df[c].isna().sum()
        pct_missing = n_missing / len(df) * 100
        sample = df[c].dropna().iloc[0] if df[c].dropna().size>0 else None
        rows.append((c, dtype, n_missing, pct_missing, sample))
    return pd.DataFrame(rows, columns=['column','dtype' ,'n_missing' ,'pct_missing','example_sample'])

data_dict = make_data_dict(df)
data_dict.to_csv('../reports/data_dictionary.csv', index=False)

# %%
data_dict.head(5)
# Out:
#           column    dtype  n_missing  pct_missing example_sample
# 0        country   object          0          0.0    Afghanistan
# 1  location_name   object          0          0.0          Kabul
# 2       latitude  float64          0          0.0          34.52
# 3      longitude  float64          0          0.0          69.18
# 4       timezone   object          0          0.0     Asia/Kabul

# %%
data_dict.sample(n=5)
# Out:
#                          column    dtype  n_missing  pct_missing  \
# 15                  pressure_in  float64          0          0.0
# 37                     moonrise   object          0          0.0
# 30  air_quality_Sulphur_dioxide  float64          0          0.0
# 40            moon_illumination    int64          0          0.0
# 34   air_quality_gb-defra-index    int64          0          0.0
#
#    example_sample
# 15          29.89
# 37       12:12 PM
# 30            0.2
# 40             55
# 34              1

# %%
missing_cols = data_dict[data_dict['n_missing'] > 0]['column'].tolist()
print("Columns with missing values:", missing_cols)
df['condition_text'].value_counts()
# Out:
# Columns with missing values: []
# condition_text
# Partly cloudy                                  30339
# Sunny                                          30136
# Patchy rain nearby                              8044
# Partly Cloudy                                   5264
# Overcast                                        4612
# Clear                                           4243
# Mist                                            3045
# Light rain                                      2877
# Light rain shower                               2360
# Cloudy                                           951
# Fog                                              900
# Moderate or heavy rain with thunder              853
# Moderate rain                                    723
# Patchy light rain with thunder                   593
# Light drizzle                                    424
# Patchy light drizzle                             315
# Moderate or heavy rain shower                    226
# Thundery outbreaks in nearby                     209
# Light snow                                       189
# Patchy light rain in area with thunder           170
# Patchy light rain                                156
# Moderate rain at times                            87
# Heavy snow                                        58
# Freezing fog                                      54
# Heavy rain                                        45
# Light snow showers                                42
# Moderate snow                                     36
# Light freezing rain                               35
# Patchy rain possible                              35
# Moderate or heavy snow showers                    35
# Light sleet                                       33
# Patchy light snow                                 29
# Thundery outbreaks possible                       24
# Blowing snow                                      20
# Patchy heavy snow                                 15
# Torrential rain shower                            11
# Heavy rain at times                               10
# Moderate or heavy rain in area with thunder        9
# Light sleet showers                                7
# Patchy moderate snow                               6
# Blizzard                                           5
# Patchy light snow in area with thunder             5
# Moderate or heavy sleet                            3
# Freezing drizzle                                   2
# Moderate or heavy snow in area with thunder        2
# Patchy snow nearby                                 2
# Patchy snow possible                               1
# Name: count, dtype: int64

# %% [markdown]
# ### Handling Missing Values

# %%
df['condition_text'] = df['condition_text'].fillna('Unknown')
numeric_cols = ['temperature_celsius', 'temperature_fahrenheit',
    'wind_mph', 'wind_kph', 'wind_degree',
    'pressure_mb', 'pressure_in',
    'precip_mm', 'precip_in',
    'humidity']
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

df['last_updated'] = pd.to_datetime(df['last_updated'], format='%d-%m-%Y %H:%M')

# %%
df = df.drop_duplicates()

# %% [markdown]
# # Anomalies - assess the quality and consistency of data

# %% [markdown]
# ### Identify anomalies - numerical

# %%
df_clean = df.copy()

# %%
numeric_cols = [
    'temperature_celsius', 'temperature_fahrenheit', 
    'wind_mph', 'wind_kph', 'wind_degree', 
    'pressure_mb', 'pressure_in', 
    'precip_mm', 'precip_in', 
    'humidity', 'cloud', 
    'feels_like_celsius', 'feels_like_fahrenheit',
    'visibility_km', 'visibility_miles', 
    'uv_index', 'gust_mph', 'gust_kph', 
    'air_quality_Carbon_Monoxide', 'air_quality_Ozone', 
    'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide', 
    'air_quality_PM2.5', 'air_quality_PM10', 
    'air_quality_us-epa-index', 'air_quality_gb-defra-index', 
    'moon_illumination'
]

df[numeric_cols].describe().to_csv('../reports/numeric_cols_full_description.csv', index=False)
df[numeric_cols].describe()
# Out:
#        temperature_celsius  temperature_fahrenheit      wind_mph  \
# count         97240.000000            97240.000000  97240.000000
# mean             22.790612               73.024825      8.243009
# std               8.895832               16.012298      7.885557
# min             -24.900000              -12.800000      2.200000
# 25%              18.100000               64.600000      4.000000
# 50%              25.000000               77.000000      6.900000
# 75%              28.300000               82.900000     11.400000
# max              49.200000              120.600000   1841.200000
#
#            wind_kph   wind_degree   pressure_mb   pressure_in     precip_mm  \
# count  97240.000000  97240.000000  97240.000000  97240.000000  97240.000000
# mean      13.269109    170.873601   1013.964613     29.941723      0.140767
# std       12.688198    102.713844     11.388608      0.336250      0.599729
# min        3.600000      1.000000    947.000000     27.960000      0.000000
# 25%        6.500000     83.000000   1010.000000     29.830000      0.000000
# 50%       11.200000    165.000000   1013.000000     29.920000      0.000000
# 75%       18.400000    256.000000   1017.000000     30.050000      0.030000
# max     2963.200000    360.000000   3006.000000     88.770000     42.240000
#
#           precip_in      humidity  ...      gust_kph  \
# count  97240.000000  97240.000000  ...  97240.000000
# mean       0.005347     64.146010  ...     18.560137
# std        0.023697     24.190017  ...     14.688076
# min        0.000000      2.000000  ...      3.600000
# 25%        0.000000     47.000000  ...     10.500000
# 50%        0.000000     69.000000  ...     15.900000
# 75%        0.000000     83.000000  ...     24.400000
# max        1.660000    100.000000  ...   2970.400000
#
#        air_quality_Carbon_Monoxide  air_quality_Ozone  \
# count                 97240.000000       97240.000000
# mean                    517.538150          62.801112
# std                     845.100253          32.269620
# min                   -9999.000000           0.000000
# 25%                     238.650000          42.000000
# 50%                     327.450000          60.000000
# 75%                     507.400000          79.000000
# max                   38879.398000         480.700000
#
#        air_quality_Nitrogen_dioxide  air_quality_Sulphur_dioxide  \
# count                  97240.000000                 97240.000000
# mean                      15.807415                    11.270508
# std                       26.067670                    40.837907
# min                        0.000000                 -9999.000000
# 25%                        1.295000                     0.800000
# 50%                        4.900000                     2.405000
# 75%                       17.945000                     9.065000
# max                      427.700000                   521.330000
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# count       97240.000000      97240.000000              97240.000000
# mean           26.167867         53.784536                  1.760911
# std            40.855679        164.293592                  0.981908
# min             0.168000      -1848.150000                  1.000000
# 25%             7.400000         10.900000                  1.000000
# 50%            15.170000         22.200000                  1.000000
# 75%            29.970000         46.065000                  2.000000
# max          1614.100000       6037.290000                  6.000000
#
#        air_quality_gb-defra-index  moon_illumination
# count                97240.000000       97240.000000
# mean                     2.761940          49.719971
# std                      2.568171          35.122040
# min                      1.000000           0.000000
# 25%                      1.000000          15.000000
# 50%                      2.000000          50.000000
# 75%                      3.000000          85.000000
# max                     10.000000         100.000000
#
# [8 rows x 27 columns]

# %%
from scipy import stats
import numpy as np

z_scores = np.abs(stats.zscore(df[numeric_cols]))
anomalies = (z_scores > 3).any(axis=1) 
df_anomalies = df[anomalies]
df_anomalies.to_csv('../reports/numeric_cols_zscore_anomalies.csv', index=False)
df_anomalies
# Out:
#             country     location_name  latitude  longitude          timezone  \
# 3           Andorra  Andorra La Vella   42.5000     1.5200    Europe/Andorra
# 4            Angola            Luanda   -8.8400    13.2300     Africa/Luanda
# 13       Bangladesh             Dhaka   23.7200    90.4100        Asia/Dhaka
# 23           Brazil              Bras   -2.0800   -58.1700    America/Manaus
# 32           Canada            Ottawa   45.4200   -75.7000   America/Toronto
# ...             ...               ...       ...        ...               ...
# 97168   New Zealand        Wellington  -41.3000   174.7833  Pacific/Auckland
# 97177         Palau             Koror    7.3333   134.4833     Pacific/Palau
# 97196  Saudi Arabia            Riyadh   24.6408    46.7728       Asia/Riyadh
# 97207   South Korea             Seoul   37.5664   126.9997        Asia/Seoul
# 97213        Sweden         Stockholm   59.3333    18.0500  Europe/Stockholm
#
#        last_updated_epoch        last_updated  temperature_celsius  \
# 3              1715849100 2024-05-16 10:45:00                  6.3
# 4              1715849100 2024-05-16 09:45:00                 26.0
# 13             1715849100 2024-05-16 14:45:00                 38.4
# 23             1715849100 2024-05-16 04:45:00                 23.1
# 32             1715849100 2024-05-16 04:45:00                 12.0
# ...                   ...                 ...                  ...
# 97168          1759046400 2025-09-28 21:00:00                 16.2
# 97177          1759045500 2025-09-28 16:45:00                 31.0
# 97196          1759046400 2025-09-28 11:00:00                 35.3
# 97207          1759047300 2025-09-28 17:15:00                 21.2
# 97213          1759047300 2025-09-28 10:15:00                 10.3
#
#        temperature_fahrenheit condition_text  ...  air_quality_PM2.5  \
# 3                        43.3  Light drizzle  ...              0.700
# 4                        78.8  Partly cloudy  ...            183.400
# 13                      101.2  Partly Cloudy  ...             49.700
# 23                       73.6            Fog  ...              0.500
# 32                       53.6  Partly cloudy  ...              5.000
# ...                       ...            ...  ...                ...
# 97168                    61.2  Partly Cloudy  ...             12.765
# 97177                    87.8  Partly cloudy  ...              7.400
# 97196                    95.5          Sunny  ...            158.545
# 97207                    70.2  Partly cloudy  ...             65.305
# 97213                    50.5            Fog  ...              5.550
#
#        air_quality_PM10  air_quality_us-epa-index air_quality_gb-defra-index  \
# 3                 0.900                         1                          1
# 4               262.300                         5                         10
# 13               57.000                         3                          6
# 23                0.500                         1                          1
# 32                5.500                         1                          1
# ...                 ...                       ...                        ...
# 97168            17.575                         1                          2
# 97177             8.880                         1                          1
# 97196          1316.280                         5                         10
# 97207            70.855                         3                          9
# 97213            11.285                         1                          1
#
#        sunrise   sunset  moonrise     moonset       moon_phase  \
# 3      6:31 AM  9:11 PM   2:12 PM     3:31 AM   Waxing Gibbous
# 4      6:12 AM  5:55 PM   1:17 PM    12:38 AM   Waxing Gibbous
# 13     5:16 AM  6:34 PM  12:28 PM    12:58 AM   Waxing Gibbous
# 23     5:49 AM  5:50 PM   1:05 PM    12:39 AM   Waxing Gibbous
# 32     5:31 AM  8:28 PM   1:31 PM     2:49 AM   Waxing Gibbous
# ...        ...      ...       ...         ...              ...
# 97168  6:00 AM  6:23 PM   8:42 AM  No moonset  Waxing Crescent
# 97177  5:51 AM  5:55 PM  10:37 AM    10:29 PM  Waxing Crescent
# 97196  5:44 AM  5:43 PM  11:23 AM     9:49 PM  Waxing Crescent
# 97207  6:24 AM  6:20 PM  12:31 PM     9:35 PM  Waxing Crescent
# 97213  6:46 AM  6:29 PM   3:56 PM     7:13 PM  Waxing Crescent
#
#        moon_illumination
# 3                     55
# 4                     55
# 13                    55
# 23                    55
# 32                    55
# ...                  ...
# 97168                 27
# 97177                 28
# 97196                 30
# 97207                 28
# 97213                 31
#
# [11463 rows x 41 columns]

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(15, 8))
sns.boxplot(data=df[numeric_cols])
plt.xticks(rotation=45)
plt.title("Box Plot of Numeric Columns")
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df['temperature_celsius'], df['humidity'], label='Normal', alpha=0.5)
plt.scatter(df_anomalies['temperature_celsius'], df_anomalies['humidity'], color='red', label='Anomalies')
plt.xlabel('Temperature (°C)')
plt.ylabel('Humidity (%)')
plt.title('Temperature vs Humidity with Anomalies Highlighted')
plt.legend()
plt.show()

# %%
sns.heatmap(z_scores, cmap='coolwarm', cbar=True)
plt.title("Z-Score Heatmap of Numeric Columns")
plt.show()

# %% [markdown]
# ### Handle anomalies - numerical

# %%
df_clean[numeric_cols] = df_clean[numeric_cols].mask(z_scores > 3)

# %%
df_clean.sample(n=10)
# Out:
#                         country      location_name  latitude  longitude  \
# 48661          Papua New Guinea       Port Moresby   -9.4647   147.1925
# 70933  United States of America  Washington Harbor   48.0792  -123.0439
# 34140                 Argentina       Buenos Aires  -34.5875   -58.6725
# 91690                  Malaysia       Kuala Lumpur    3.1667   101.7000
# 24008              Saudi Arabia             Riyadh   24.6400    46.7700
# 83495                   Liberia           Monrovia    6.3106   -10.8047
# 26007       Antigua and Barbuda       Saint John's   17.1200   -61.8500
# 53141                  Pakistan          Islamabad   33.7000    73.1667
# 52330                Luxembourg         Luxembourg   49.6117     6.1300
# 62277                 Mauritius         Port Louis  -20.1619    57.4989
#
#                              timezone  last_updated_epoch        last_updated  \
# 48661            Pacific/Port_Moresby          1737540900 2025-01-22 20:15:00
# 70933             America/Los_Angeles          1747386000 2025-05-16 02:00:00
# 34140  America/Argentina/Buenos_Aires          1731142800 2024-11-09 06:00:00
# 91690               Asia/Kuala_Lumpur          1756627200 2025-08-31 16:00:00
# 24008                     Asia/Riyadh          1726570800 2024-09-17 14:00:00
# 83495                 Africa/Monrovia          1753000200 2025-07-20 08:30:00
# 26007                 America/Antigua          1727517600 2024-09-28 06:00:00
# 53141                    Asia/Karachi          1739527200 2025-02-14 15:00:00
# 52330               Europe/Luxembourg          1739183400 2025-02-10 11:30:00
# 62277                Indian/Mauritius          1743584400 2025-04-02 13:00:00
#
#        temperature_celsius  temperature_fahrenheit     condition_text  ...  \
# 48661                 27.0                    80.5  Light rain shower  ...
# 70933                  8.2                    46.8           Overcast  ...
# 34140                 17.2                    63.0              Sunny  ...
# 91690                 33.0                    91.4      Partly cloudy  ...
# 24008                 40.1                   104.2              Sunny  ...
# 83495                 25.1                    77.2      Partly cloudy  ...
# 26007                 28.4                    83.1      Partly cloudy  ...
# 53141                 20.5                    68.8              Sunny  ...
# 52330                  2.3                    36.1               Mist  ...
# 62277                 30.3                    86.5           Overcast  ...
#
#        air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 48661             15.540            16.095                       2.0
# 70933              3.330             4.440                       1.0
# 34140             13.505            20.165                       1.0
# 91690             77.515            77.885                       4.0
# 24008             76.405               NaN                       4.0
# 83495             22.200            28.120                       2.0
# 26007             15.557            29.486                       2.0
# 53141             34.595            46.435                       2.0
# 52330             39.405            40.700                       2.0
# 62277              7.585            11.285                       1.0
#
#       air_quality_gb-defra-index  sunrise   sunset     moonrise   moonset  \
# 48661                          2  6:05 AM  6:40 PM  No moonrise  12:21 PM
# 70933                          1  5:32 AM  8:46 PM     12:30 AM   7:52 AM
# 34140                          2  5:46 AM  7:33 PM     12:34 PM   1:57 AM
# 91690                         10  7:08 AM  7:19 PM      1:00 PM  12:21 AM
# 24008                         10  5:40 AM  5:54 PM      5:36 PM   4:37 AM
# 83495                          2  6:36 AM  7:03 PM      2:06 AM   2:59 PM
# 26007                          2  5:57 AM  5:58 PM      2:32 AM   3:43 PM
# 53141                          3  6:53 AM  5:51 PM      7:38 PM   7:51 AM
# 52330                          4  7:54 AM  5:47 PM      3:07 PM   7:19 AM
# 62277                          1  6:17 AM  6:09 PM     10:21 AM   9:22 PM
#
#             moon_phase  moon_illumination
# 48661     Last Quarter                 53
# 70933   Waning Gibbous                 88
# 34140    First Quarter                 47
# 91690    First Quarter                 44
# 24008   Waxing Gibbous                 98
# 83495  Waning Crescent                 28
# 26007  Waning Crescent                 20
# 53141   Waning Gibbous                 99
# 52330   Waxing Gibbous                 93
# 62277  Waxing Crescent                 16
#
# [10 rows x 41 columns]

# %%
df_clean[numeric_cols] = df_clean[numeric_cols].fillna(df[numeric_cols].mean())

# %%
df_clean = df_clean[~anomalies]

# %%
df_clean.shape[0]
# Out:
# 85777

# %%
df.shape[0]
# Out:
# 97240

# %%
plt.figure(figsize=(10, 6))
plt.scatter(df_clean['temperature_celsius'], df_clean['humidity'], alpha=0.6)
plt.xlabel('Temperature (°C)')
plt.ylabel('Humidity (%)')
plt.title('Temperature vs Humidity (Anomaly-Free)')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

# Plot original data (with anomalies)
plt.scatter(df['temperature_celsius'], df['humidity'], 
            alpha=0.3, label='Original (with anomalies)', color='gray')

# Plot cleaned data (anomaly-free)
plt.scatter(df_clean['temperature_celsius'], df_clean['humidity'], 
            alpha=0.6, label='Anomaly-Free', color='blue')

plt.xlabel('Temperature (°C)')
plt.ylabel('Humidity (%)')
plt.title('Temperature vs Humidity: Original vs Anomaly-Free')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# ### Identify anomalies - categorical

# %%
categorical_cols = ['condition_text', 'wind_direction', 'moon_phase']

for col in categorical_cols:
    print(f"{col} unique values:")
    print(df[col].unique())
    print("\n")
# Out:
# condition_text unique values:
# ['Partly Cloudy' 'Partly cloudy' 'Sunny' 'Light drizzle' 'Clear'
#  'Overcast' 'Moderate or heavy rain with thunder'
#  'Patchy light rain in area with thunder' 'Fog'
#  'Patchy light rain with thunder' 'Patchy rain nearby' 'Light rain' 'Mist'
#  'Cloudy' 'Thundery outbreaks in nearby' 'Moderate rain'
#  'Light rain shower' 'Moderate rain at times'
#  'Moderate or heavy rain shower' 'Heavy rain at times' 'Patchy light rain'
#  'Patchy light drizzle' 'Thundery outbreaks possible'
#  'Patchy rain possible' 'Moderate or heavy rain in area with thunder'
#  'Heavy rain' 'Torrential rain shower' 'Freezing fog'
#  'Moderate or heavy snow showers' 'Light sleet' 'Blizzard' 'Moderate snow'
#  'Light snow' 'Light sleet showers' 'Light freezing rain' 'Heavy snow'
#  'Blowing snow' 'Patchy heavy snow' 'Light snow showers'
#  'Moderate or heavy sleet' 'Patchy light snow' 'Patchy moderate snow'
#  'Freezing drizzle' 'Moderate or heavy snow in area with thunder'
#  'Patchy snow nearby' 'Patchy snow possible'
#  'Patchy light snow in area with thunder']
#
#
# wind_direction unique values:
# ['NNW' 'NW' 'W' 'SW' 'SSE' 'E' 'N' 'SE' 'ESE' 'NNE' 'S' 'WSW' 'SSW' 'ENE'
#  'NE' 'WNW']
#
#
# moon_phase unique values:
# ['Waxing Gibbous' 'Full Moon' 'Waning Gibbous' 'Last Quarter'
#  'Waning Crescent' 'New Moon' 'Waxing Crescent' 'First Quarter']

# %% [markdown]
# ### Handle Categorical Anomaly

# %%
df_clean['condition_text'] = df_clean['condition_text'].str.lower().str.strip()

# %%
df_clean.head(5)
# Out:
#                country location_name  latitude  longitude  \
# 0          Afghanistan         Kabul     34.52      69.18
# 1              Albania        Tirana     41.33      19.82
# 2              Algeria       Algiers     36.76       3.05
# 5  Antigua and Barbuda  Saint John's     17.12     -61.85
# 6            Argentina  Buenos Aires    -34.59     -58.67
#
#                          timezone  last_updated_epoch        last_updated  \
# 0                      Asia/Kabul          1715849100 2024-05-16 13:15:00
# 1                   Europe/Tirane          1715849100 2024-05-16 10:45:00
# 2                  Africa/Algiers          1715849100 2024-05-16 09:45:00
# 5                 America/Antigua          1715849100 2024-05-16 04:45:00
# 6  America/Argentina/Buenos_Aires          1715849100 2024-05-16 05:45:00
#
#    temperature_celsius  temperature_fahrenheit condition_text  ...  \
# 0                 26.6                    79.8  partly cloudy  ...
# 1                 19.0                    66.2  partly cloudy  ...
# 2                 23.0                    73.4          sunny  ...
# 5                 26.0                    78.8  partly cloudy  ...
# 6                  8.0                    46.4          clear  ...
#
#    air_quality_PM2.5  air_quality_PM10  air_quality_us-epa-index  \
# 0                8.4              26.6                       1.0
# 1                1.1               2.0                       1.0
# 2               10.4              18.4                       1.0
# 5                1.2               4.5                       1.0
# 6                4.0               5.3                       1.0
#
#   air_quality_gb-defra-index  sunrise   sunset  moonrise  moonset  \
# 0                          1  4:50 AM  6:50 PM  12:12 PM  1:11 AM
# 1                          1  5:21 AM  7:54 PM  12:58 PM  2:14 AM
# 2                          1  5:40 AM  7:50 PM   1:15 PM  2:14 AM
# 5                          1  5:36 AM  6:32 PM   1:05 PM  1:14 AM
# 6                          1  7:43 AM  5:59 PM   2:36 PM  1:04 AM
#
#        moon_phase  moon_illumination
# 0  Waxing Gibbous                 55
# 1  Waxing Gibbous                 55
# 2  Waxing Gibbous                 55
# 5  Waxing Gibbous                 55
# 6  Waxing Gibbous                 55
#
# [5 rows x 41 columns]

# %%
for col in categorical_cols:
    plt.figure(figsize=(10, 4))
    sns.countplot(data=df_clean, x=col, order=df_clean[col].value_counts().index)
    plt.xticks(rotation=45)
    plt.title(f"Distribution of {col}")
    plt.tight_layout()
    plt.show()

# %%
df_clean['last_updated'] = df['last_updated']

# %%
df_clean['country'] = df['country']

# %% [markdown]
# # Data Coverage

# %%
df.isnull().sum()
df[numeric_cols].isnull().mean() * 100
# Out:
# temperature_celsius             0.0
# temperature_fahrenheit          0.0
# wind_mph                        0.0
# wind_kph                        0.0
# wind_degree                     0.0
# pressure_mb                     0.0
# pressure_in                     0.0
# precip_mm                       0.0
# precip_in                       0.0
# humidity                        0.0
# cloud                           0.0
# feels_like_celsius              0.0
# feels_like_fahrenheit           0.0
# visibility_km                   0.0
# visibility_miles                0.0
# uv_index                        0.0
# gust_mph                        0.0
# gust_kph                        0.0
# air_quality_Carbon_Monoxide     0.0
# air_quality_Ozone               0.0
# air_quality_Nitrogen_dioxide    0.0
# air_quality_Sulphur_dioxide     0.0
# air_quality_PM2.5               0.0
# air_quality_PM10                0.0
# air_quality_us-epa-index        0.0
# air_quality_gb-defra-index      0.0
# moon_illumination               0.0
# dtype: float64

# %%
plt.figure(figsize=(23, 10))
sns.heatmap(df_clean[numeric_cols].corr(), annot=True, cmap='coolwarm')
plt.title("Correlation Matrix of Numeric Columns")
plt.show()

# %% [markdown]
# # Convert Units (Remove Redundancy)

# %%
df_clean = df_clean.drop(columns=[
    'temperature_fahrenheit', 'wind_kph', 'pressure_in',
    'precip_in', 'visibility_miles', 'feels_like_fahrenheit', 'gust_kph'
])

# %% [markdown]
# # Normalize Values

# %% [markdown]
# ### StandardScaler (Z-score normalization)

# %%
modified_numeric_cols = [
    'temperature_celsius', 
    'wind_mph',  'wind_degree', 
    'pressure_mb',  
    'precip_mm',  
    'humidity', 'cloud', 
    'feels_like_celsius', 
    'visibility_km',  
    'uv_index', 'gust_mph',  
    'air_quality_Carbon_Monoxide', 'air_quality_Ozone', 
    'air_quality_Nitrogen_dioxide', 'air_quality_Sulphur_dioxide', 
    'air_quality_PM2.5', 'air_quality_PM10', 
    'air_quality_us-epa-index', 'air_quality_gb-defra-index', 
    'moon_illumination'
]

# %% [markdown]
# ###  StandardScaler

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
scaled_array = scaler.fit_transform(df_clean[modified_numeric_cols]) 

df_scaled = pd.DataFrame(scaled_array, columns=modified_numeric_cols, index=df_clean.index)

# %%
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# Original
original = df_clean[modified_numeric_cols]

# Standard Scaled
standard_scaled = pd.DataFrame(StandardScaler().fit_transform(original), 
                               columns=modified_numeric_cols, index=df_clean.index)

# %%
features_to_plot = ['temperature_celsius', 'humidity', 'uv_index']

for feature in features_to_plot:
    plt.figure(figsize=(15, 4))

    plt.subplot(1, 3, 1)
    sns.histplot(original[feature], kde=True, color='gray')
    plt.title(f'Original: {feature}')

    plt.subplot(1, 3, 2)
    sns.histplot(standard_scaled[feature], kde=True, color='blue')
    plt.title(f'Standard Scaled: {feature}')


    plt.tight_layout()
    plt.show()

# %%
for feature in features_to_plot:
    melted = pd.DataFrame({
        'Original': original[feature],
        'Standard': standard_scaled[feature]
    }).melt(var_name='Scaling', value_name='Value')
    
    plt.figure(figsize=(8, 6))
    sns.boxplot(x='Scaling', y='Value',hue='Scaling', data=melted, palette=['gray', 'blue'], legend=False)
    plt.title(f'Boxplot Comparison: {feature}')
    plt.grid(axis='y', linestyle='--', alpha=0.6)
    plt.tight_layout()
    plt.show()

# %%
for feature in features_to_plot:
    plt.figure(figsize=(12, 4))
    plt.plot(original[feature].values[:100], label='Original', color='gray')
    plt.plot(standard_scaled[feature].values[:100], label='Standard', color='blue')
    plt.title(f'Row-wise Comparison: {feature} (First 100 rows)')
    plt.legend()
    plt.grid(True)
    plt.show()

# %% [markdown]
# # FINAL DATA

# %%
non_numeric = df_clean.drop(columns=modified_numeric_cols)
df_final = pd.concat([standard_scaled, non_numeric], axis=1)

# %% [markdown]
# ### Aggregate to Monthly Averages

# %%
# Convert timestamp column
df_final['last_updated'] = pd.to_datetime(df_final['last_updated'])

# Extract month period
df_final['month'] = df_final['last_updated'].dt.to_period('M')

# Group by month and location
df_monthly = df_final.groupby(['month', 'country', 'location_name', 'latitude', 'longitude']).mean(numeric_only=True).reset_index()

# %%
df_monthly.to_csv('../data/processed/final_weather_monthly.csv', index=False)

# %%
df_monthly.columns
# Out:
# Index(['month', 'country', 'location_name', 'latitude', 'longitude',
#        'temperature_celsius', 'wind_mph', 'wind_degree', 'pressure_mb',
#        'precip_mm', 'humidity', 'cloud', 'feels_like_celsius', 'visibility_km',
#        'uv_index', 'gust_mph', 'air_quality_Carbon_Monoxide',
#        'air_quality_Ozone', 'air_quality_Nitrogen_dioxide',
#        'air_quality_Sulphur_dioxide', 'air_quality_PM2.5', 'air_quality_PM10',
#        'air_quality_us-epa-index', 'air_quality_gb-defra-index',
#        'moon_illumination', 'last_updated_epoch'],
#       dtype='object')

# %%
df_final = pd.concat([df_scaled, df_clean[categorical_cols], df_clean[['last_updated', 'country']]], axis=1)

# %%
df_final.to_csv('../data/processed/normalized_weather_data.csv', index=False)

# %%
df_final.shape
# Out:
# (85777, 25)
